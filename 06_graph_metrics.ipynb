# %%
import networkx as nx
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 1. Defining Parameters

# %%
BASE_PATH = r"./Final_Graph"
GRAPHML_PATH = os.path.join(BASE_PATH, "ml_ready_graph.graphml")

# %% [markdown]
# # 2. Graph Loading

# %%
G = nx.read_graphml(GRAPHML_PATH)

# %% [markdown]
# # 3. Calculating Metrics

# %%
total_nodes = G.number_of_nodes()
total_edges = G.number_of_edges()
print(f"Number of Nodes: {total_nodes}")
print(f"Number of Edges: {total_edges}")
# Out:
# Number of Nodes: 48739
# Number of Edges: 73076

# %% [markdown]
# ## 3.1. Number of Connected Components

# %%
num_components = nx.number_connected_components(G)

# %% [markdown]
# ## 3.2. Density

# %%
density = nx.density(G)

# %% [markdown]
# ## 3.3. Clustering Coefficient

# %%
G_simple = nx.Graph(G)
clustering_global = nx.average_clustering(G_simple)

# %%
print(f"Number of Connected Components: {num_components}")
print(f"Graph Density: {density:.6f}")
print(f"Mean Clustering Coefficient: {clustering_global:.4f}")
# Out:
# Number of Connected Components: 1
# Graph Density: 0.000062
# Mean Clustering Coefficient: 0.0354

# %% [markdown]
# ## 3.4. Centrality

# %%
degree_centrality = nx.degree_centrality(G)

# %% [markdown]
# ## 3.5.  Betweenness

# %%
num_nodes = G.number_of_nodes()
K_SAMPLES = min(5000, max(500, int(num_nodes * 0.10)))

print(f"Sampling k={K_SAMPLES} for Betweenness Calculation.")

betweenness_centrality = nx.betweenness_centrality(
    G, 
    k=K_SAMPLES,
    weight='length',
    normalized=True,
    seed=42
)
# Out:
# Sampling k=4873 for Betweenness Calculation.

# %%
# betweenness_centrality = nx.betweenness_centrality(G, weight='length')

# %% [markdown]
# ## 3.6. Closeness

# %%
closeness_centrality = nx.closeness_centrality(
    G,
    distance='length'
)

# %%
nodes_df = pd.DataFrame({
    'node_id': list(G.nodes()),
    'degree_centrality': [degree_centrality[n] for n in G.nodes()],
    'betweenness_centrality': [betweenness_centrality[n] for n in G.nodes()],
    'closeness_centrality': [closeness_centrality[n] for n in G.nodes()],
})

# %%
nodes_df.head(10)
# Out:
#                                    node_id  degree_centrality  \
# 0   (333543.4992779681, 7398639.456472073)           0.000062
# 1   (333505.9441709011, 7398611.718505675)           0.000062
# 2   (333532.3047175107, 7398555.910928236)           0.000062
# 3  (333615.75092158274, 7398689.472791225)           0.000062
# 4   (333679.6703566854, 7398681.769958133)           0.000062
# 5   (333668.34047255793, 7398706.38338146)           0.000062
# 6   (333742.5070595381, 7398583.127264978)           0.000062
# 7   (333654.73178283765, 7398480.01810501)           0.000062
# 8   (333678.4853853023, 7398487.375790649)           0.000062
# 9  (333625.93611473066, 7398478.683431058)           0.000062
#
#    betweenness_centrality  closeness_centrality
# 0                0.001009              0.013990
# 1                0.000257              0.013798
# 2                0.001402              0.014185
# 3                0.000728              0.013799
# 4                0.000063              0.013793
# 5                0.000041              0.013610
# 6                0.000075              0.013980
# 7                0.000174              0.014582
# 8                0.000114              0.014375
# 9                0.000021              0.014378

# %%
np.mean(list(degree_centrality.values()))
# Out:
# np.float64(6.15262498613826e-05)

# %%
np.mean(list(closeness_centrality.values()))
# Out:
# np.float64(0.014129446842845774)

# %%
np.mean(list(betweenness_centrality.values()))
# Out:
# np.float64(0.0014920473856168252)
